# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy.stats import kruskal,chisquare,chi2_contingency
from imblearn.over_sampling import SMOTE
from catboost import CatBoostClassifier
import funcs
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.mixture import GaussianMixture
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
import itertools
import warnings
warnings.filterwarnings('ignore') # for Kmeans memory leak warning

# %%
data = pd.read_csv("../../adni/objects/adni_df.csv", index_col=0)
data.head()
# Out:
#    RID  PTHAND  PTMARRY  PTEDUCAT  PTNOTRT  PTHOME  PTPLANG  PTETHCAT  \
# 1    2       2        1        16        1       1        1         2
# 2    3       1        1        18        1       3        1         2
# 3    4       1        1        10        0       1        2         1
# 4    5       1        1        16        1       1        1         2
# 5    6       1        1        13        1       1        1         2
#
#    PTRACCAT        age  ...  RCT29  RCT3  RCT392  RCT4  RCT5  RCT6  RCT8  \
# 1         5  74.333333  ...    0.2    19     1.1    21    19    15   5.6
# 2         5  81.250000  ...    0.1    21     1.3    16    19    19   6.9
# 3         5  67.583333  ...    0.1    16     1.2    23    18    25   6.0
# 4         5  73.666667  ...    0.2    16     1.0    17    24    14   5.7
# 5         5  80.416667  ...    0.2    19     1.1    16    19    23   5.3
#
#    RCT9  apoe  DIAGNOSIS
# 1   3.0     2    Control
# 2   3.5     3         AZ
# 3   2.9     2        MCI
# 4   3.2     2    Control
# 5   4.5     2        MCI
#
# [5 rows x 116 columns]

# %%
df = data.copy()

# %%
df = funcs.preproc_df(df)

# %% [markdown]
# ## Filter-based feature selection

# %% [markdown]
# ### KW test for continuous vars & Kramer's V for categorical vars

# %%
cat_features = [col for col in df.columns if (
    col.startswith("NX") or
    col.startswith("PX") or
    col.startswith("PT") or
    col.startswith("MH") or
    (col.startswith("GD") and col != "GDTOTAL") or
    col in ["mother", "father", "HMSCORE", "apoe"]
)]

# %%
cont_features = [col for col in df.columns if 
                 col not in cat_features and 
                col != "DIAGNOSIS"]

# %%
kr_stat = []
kr_p = []
for f in cont_features:
    groups = [df[f][df['DIAGNOSIS'] == cat] for cat in df['DIAGNOSIS'].unique()]
    kruskal_result = kruskal(*groups)
    kr_stat.append(kruskal_result.statistic)
    kr_p.append(kruskal_result.pvalue)

# %%
result_kw = pd.DataFrame({"feature": cont_features,
                         "stat": kr_stat,
                         "pvalue": kr_p})

# %%
alpha=0.05
for f in cont_features:
    groups = [df[f][df['DIAGNOSIS'] == cat] for cat in df['DIAGNOSIS'].unique()]
    
    # Perform omnibus Kruskal-Wallis test
    kruskal_result = kruskal(*groups)
    
    # Store the omnibus test result
    kr_stat.append(kruskal_result.statistic)
    kr_p.append(kruskal_result.pvalue)
    
    # Perform pairwise Kruskal-Wallis tests between all combinations of categories in DIAGNOSIS
    pairwise_significant = True
    for cat1, cat2 in itertools.combinations(df['DIAGNOSIS'].unique(), 2):
        group1 = df[f][df['DIAGNOSIS'] == cat1]
        group2 = df[f][df['DIAGNOSIS'] == cat2]
        
        # Perform pairwise Kruskal-Wallis test
        pairwise_result = kruskal(group1, group2)
        
        # Check if p-value is below the threshold
        if pairwise_result.pvalue >= alpha:
            pairwise_significant = False
            break  # If any pairwise comparison is not significant, stop checking

    # Only append to results if all pairwise comparisons are significant
    if pairwise_significant:
        print(f"Feature {f} passed all pairwise comparisons with p < {alpha}")
# Out:
# Feature LIMMTOTAL passed all pairwise comparisons with p < 0.05
# Feature LDELTOTAL passed all pairwise comparisons with p < 0.05
# Feature HMT15 passed all pairwise comparisons with p < 0.05
# Feature HMT16 passed all pairwise comparisons with p < 0.05
# Feature hsi passed all pairwise comparisons with p < 0.05

# %% [markdown]
# ### Cont features significant across AD, MCI and HC at p = 0.01

# %%
result_kw[result_kw['pvalue'] < 0.01]
# Out:
#       feature        stat         pvalue
# 5     VSPULSE   13.438741   1.207298e-03
# 7   LIMMTOTAL  436.018627   2.088133e-95
# 8   LDELTOTAL  543.719714  8.565729e-119
# 9     GDTOTAL   68.551723   1.300716e-15
# 12     HMT100   14.056448   8.865047e-04
# 17      HMT15   25.316244   3.181614e-06
# 18      HMT16   18.727201   8.579063e-05
# 27       HMT8   16.293852   2.896242e-04
# 51        ppr   12.432641   1.996578e-03
# 52        hsi   15.228198   4.934451e-04

# %%
cont_features_sig = result_kw[result_kw['pvalue'] < 0.01].feature.tolist()

# %%
cr = []

for f in cat_features:
    cont_tab = pd.crosstab(index=data['DIAGNOSIS'], columns=data[f])
    chi2, p, dof, expected = chi2_contingency(cont_tab)
    n = cont_tab.sum().sum()
    phi2 = chi2 / n
    r, k = cont_tab.shape
    cramers_v = np.sqrt(phi2 / min(r-1, k-1))
    cr.append(cramers_v)

# %%
result_kramer = pd.DataFrame({"feature": cat_features,
                         "Kramer": cr})
result_kramer = result_kramer.sort_values(by="Kramer", ascending=False)

# %% [markdown]
# ### Cat features with at least moderate association with the outcome

# %%
result_kramer[result_kramer['Kramer'] >= 0.11]
# Out:
#      feature    Kramer
# 59  GDMEMORY  0.398052
# 66      apoe  0.218232
# 32   MHPSYCH  0.192215
# 2   PTEDUCAT  0.167799
# 51    GDDROP  0.153349
# 31    NXGAIT  0.150544
# 4     PTHOME  0.132056
# 64  GDBETTER  0.128134
# 53   GDBORED  0.127018

# %%
cat_features_sig = result_kramer[result_kramer['Kramer'] >= 0.11].feature.tolist()

# %%
feat = cont_features_sig + cat_features_sig

# %% [markdown]
# ### Model after feature selection

# %%
outcome = df['DIAGNOSIS']
outcome = outcome.replace({"Control": 0,
                  "MCI": 1,
                  "AZ": 2})

# %%
df.drop('DIAGNOSIS', axis = 1, inplace=True)

# %%
X, X_test, y, y_test = train_test_split(df[feat], outcome, test_size=0.2, random_state=43)

# %%
smote_over = SMOTE(random_state=44)
X, y = smote_over.fit_resample(X, y)

# %%
best_params_feat_selection = {'iterations': 1800, 
                              'learning_rate': 0.2736095674018922, 
                              'l2_leaf_reg': 3.531079234474505, 
                              'bagging_temperature': 0.571547709531307, 
                              'random_strength': 1.5028953428173903, 
                              'depth': 9, 
                              'min_data_in_leaf': 79,
                              'random_seed': 44,
                              'loss_function': "MultiClass",
                              'colsample_bylevel': 0.9003486064573871}

# %%
final_model = CatBoostClassifier(**best_params_feat_selection, verbose=False, cat_features = cat_features_sig)

# %%
final_model.fit(X, y)

# %%
predictions = final_model.predict(X_test)
predictions_proba = final_model.predict_proba(X_test)

# %%
funcs.metrics_merged(y_test, predictions, predictions_proba)
# Out:
#      Class    Recall  Precision  Specificity       NPV       AUC
# 0  Control  0.930233   0.784314     0.916667  0.975806  0.983615
# 1      MCI  0.711340   0.851852     0.846154  0.702128  0.900740
# 2       AD  0.742857   0.604651     0.878571  0.931818  0.932449

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[40,  3,  0],
#        [11, 69, 17],
#        [ 0,  9, 26]], dtype=int64)

# %%
n_classes = len(np.unique(y_test))
class_labels = ["Control", "MCI", "AD"]
colors = ['blue', 'red', 'green']  

plt.figure(figsize=(10, 8))

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test == i, predictions_proba[:, i]) 
    roc_auc = auc(fpr, tpr)  
    plt.plot(fpr, tpr, color=colors[i], label=f'{class_labels[i]} (AUC = {roc_auc:.2f})')


plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')  
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUROC Curves for Multi-class model')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %% [markdown]
# ## PCA

# %%
data_feat = df[feat]

# %%
pipeline = Pipeline([("scaler", StandardScaler()), ("pca", PCA(n_components=2)),])

# %%
pca_data = pd.DataFrame(
    pipeline.fit_transform(data_feat),
    columns=["PC1", "PC2"],
    index=data_feat.index
)
pca_data['outcome'] = outcome.replace({0: "Control", 1:"MCI", 2:"AZ"})
pca_step = pipeline.steps[1][1]

# %% [markdown]
# ### MCI overlaps with both Control and AD

# %%
g = sns.scatterplot(data=pca_data, x="PC1", y="PC2", hue="outcome")


g.set_xlabel(f"PC1 ({pca_step.explained_variance_ratio_[0]*100:.2f} %)")
g.set_ylabel(f"PC2 ({pca_step.explained_variance_ratio_[1]*100:.2f} %)")

#plt.savefig("../pics/PCA_with_loadings.tiff", dpi=300)
plt.show()

# %%
pca_MCI = pca_data[pca_data["outcome"] == "MCI"]

# %% [markdown]
# ### Based on selected features the optimal number of clusters in MCI group is three

# %%
inertias = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_MCI.iloc[:,0:2])
    inertias.append(kmeans.inertia_)

# Plot inertia to find the elbow
plt.plot(range(1, 10), inertias, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
#plt.savefig("../pics/Inertia.tiff", dpi=300)
plt.show()

# %%
gmm = GaussianMixture(n_components=3, covariance_type='tied')
labels = gmm.fit_predict(pca_MCI.iloc[:,0:2])

# %%
labels_MCI = np.where(labels == 0, "MCI1", np.where(labels == 1, "MCI2", "MCI3"))

# %%
pca_data["cluster"] = pca_data["outcome"]
pca_data.loc[pca_data["outcome"] == "MCI", "cluster"] = labels_MCI

# %%
g = sns.scatterplot(data=pca_data, x="PC1", y="PC2", hue="cluster")


# Add variance explained by the
g.set_xlabel(f"PC1 ({pca_step.explained_variance_ratio_[0]*100:.2f} %)")
g.set_ylabel(f"PC2 ({pca_step.explained_variance_ratio_[1]*100:.2f} %)")

#plt.savefig("../pics/PCA_with_loadings_2.tiff", dpi=300)
plt.show()

# %% [markdown]
# ### Clusters can be characterized by proximity to either HC or AD groups

# %%
grouped_data = pca_data.groupby('cluster')[['PC1', 'PC2']].mean()
Z = linkage(grouped_data, method='ward')

# Create a dendrogram to visualize the clustering
plt.figure(figsize=(10, 7))
dendrogram(Z, labels=grouped_data.index)  # 'outcome' includes AZ, Control, MCI1, MCI2, MCI3
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
#plt.savefig("../pics/dendrogram.tiff", dpi=300)
plt.show()

# %%
data_feat_cluster = data_feat.copy()
data_feat_cluster["cluster"] = pca_data["cluster"]
data_feat_cluster['RID'] = data['RID']

# %%
data_feat_cluster = data_feat_cluster[data_feat_cluster['cluster'].isin(["MCI1", "MCI2", "MCI3"])]

# %%
data_feat_cluster['cluster'] = data_feat_cluster['cluster'].replace({'MCI3': 'MCI_AD', 'MCI1':'MCI_Healthy', 'MCI2': 'MCI_Middle'})

# %%
ids_to_exclude_AD = data_feat_cluster[data_feat_cluster['cluster'] == "MCI_AD"]['RID'].to_list()
ids_to_exclude_Healthy = data_feat_cluster[data_feat_cluster['cluster'] == "MCI_Healthy"]['RID'].to_list()
ids_to_exclude_Middle = data_feat_cluster[data_feat_cluster['cluster'] == "MCI_Middle"]['RID'].to_list()

# %%
data_no_MCI_AD = data[~data['RID'].isin(ids_to_exclude_AD)].copy()
data_no_MCI_Healthy = data[~data['RID'].isin(ids_to_exclude_Healthy)].copy()
data_no_MCI_Middle = data[~data['RID'].isin(ids_to_exclude_Middle)].copy()

data_no_MCI_AD = funcs.preproc_df(data_no_MCI_AD)
data_no_MCI_Healthy = funcs.preproc_df(data_no_MCI_Healthy)
data_no_MCI_Middle = funcs.preproc_df(data_no_MCI_Middle)

# %% [markdown]
# ## Removing MCI Healthy subgroup

# %%
outcome = data_no_MCI_Healthy['DIAGNOSIS'].copy()
outcome = outcome.replace({"Control": 0,
                  "MCI": 1,
                  "AZ": 2})
data_no_MCI_Healthy.drop(['DIAGNOSIS'], axis = 1, inplace=True)

# %%
X, X_test, y, y_test = train_test_split(data_no_MCI_Healthy[feat], outcome, test_size=0.2, random_state=43)

# %%
smote_over = SMOTE(random_state=44)
X, y = smote_over.fit_resample(X, y)

# %%
final_model.fit(X, y)

# %%
predictions = final_model.predict(X_test)
predictions_proba = final_model.predict_proba(X_test)

# %%
funcs.metrics_merged(y_test, predictions, predictions_proba)
# Out:
#      Class    Recall  Precision  Specificity       NPV       AUC
# 0  Control  0.781250   0.961538     0.992366  0.948905  0.973998
# 1      MCI  0.826087   0.760000     0.661972  0.746032  0.797306
# 2       AD  0.564103   0.594595     0.879032  0.865079  0.835815

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[25,  7,  0],
#        [ 1, 76, 15],
#        [ 0, 17, 22]], dtype=int64)

# %% [markdown]
# ## Removing MCI Middle subgroup

# %%
outcome = data_no_MCI_Middle['DIAGNOSIS'].copy()
outcome = outcome.replace({"Control": 0,
                  "MCI": 1,
                  "AZ": 2})
data_no_MCI_Middle.drop(['DIAGNOSIS'], axis = 1, inplace=True)

# %%
X, X_test, y, y_test = train_test_split(data_no_MCI_Middle[feat], outcome, test_size=0.2, random_state=43)

# %%
smote_over = SMOTE(random_state=44)
X, y = smote_over.fit_resample(X, y)

# %%
final_model.fit(X, y)

# %%
predictions = final_model.predict(X_test)
predictions_proba = final_model.predict_proba(X_test)

# %%
funcs.metrics_merged(y_test, predictions, predictions_proba)
# Out:
#      Class    Recall  Precision  Specificity       NPV       AUC
# 0  Control  0.923077   0.923077     0.974138  0.974138  0.993148
# 1      MCI  0.770270   0.760000     0.777778  0.787500  0.848015
# 2       AD  0.642857   0.658537     0.876106  0.868421  0.860303

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[36,  3,  0],
#        [ 3, 57, 14],
#        [ 0, 15, 27]], dtype=int64)

# %% [markdown]
# ## Removing MCI AD subgroup

# %%
outcome = data_no_MCI_AD['DIAGNOSIS'].copy()
outcome = outcome.replace({"Control": 0,
                  "MCI": 1,
                  "AZ": 2})
data_no_MCI_AD.drop(['DIAGNOSIS'], axis = 1, inplace=True)

# %%
X, X_test, y, y_test = train_test_split(data_no_MCI_AD[feat], outcome, test_size=0.2, random_state=43)

# %%
smote_over = SMOTE(random_state=44)
X, y = smote_over.fit_resample(X, y)

# %%
final_model.fit(X, y)

# %%
predictions = final_model.predict(X_test)
predictions_proba = final_model.predict_proba(X_test)

# %%
funcs.metrics_merged(y_test, predictions, predictions_proba)
# Out:
#      Class    Recall  Precision  Specificity       NPV       AUC
# 0  Control  0.934783   0.860000     0.895522  0.952381  0.963011
# 1      MCI  0.722222   0.812500     0.922078  0.876543  0.907287
# 2       AD  0.903226   0.903226     0.963415  0.963415  0.984264

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[43,  3,  0],
#        [ 7, 26,  3],
#        [ 0,  3, 28]], dtype=int64)

# %%
importances = final_model.feature_importances_
feature_names = X.columns  # If using a DataFrame, otherwise, use the appropriate feature list

# Sort feature importances
indices = np.argsort(importances)[::-1][:10]
# Create a bar plot of feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(10), importances[indices], align="center")
plt.xticks(range(10), feature_names[indices], rotation=90)
plt.xlim([-1, 10])
plt.ylabel("Importance")
plt.xlabel("Feature")
plt.tight_layout()
plt.show()
